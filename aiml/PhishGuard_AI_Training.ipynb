# %% [markdown]
# # PhishGuard AI — Final Year Model Training & Benchmark Pipeline
# ### Google Colab Notebook for DistilBERT Fine-Tuning & Scikit-learn Comparison
#
# This notebook trains and benchmarks 4 machine learning architectures:
# 1. **TF-IDF + Logistic Regression**
# 2. **Random Forest Classifier**
# 3. **XGBoost Classifier**
# 4. **Fine-Tuned DistilBERT (PyTorch + HuggingFace Transformers)**

# %%
# !pip install -q torch transformers scikit-learn librosa shap numpy pandas
import torch
import numpy as np
print(f"CUDA Available: {torch.cuda.is_available()}")
